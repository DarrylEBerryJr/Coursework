# %% [markdown]
# ### Quiz_4

# %% [markdown]
# #### Enter username here:

# %% [markdown]
# Numerically compute:

# %% [markdown]
# $$
# \int_0^5 x^3e^{-x}\,dx
# $$

# %% [markdown]
# **Do this in two steps.**

# %% [markdown]
# #1 **Plot** the function $x^3e^{-x}$ in the interval $[0,5]$.

# %% [markdown]
# #2 **Calculate** the integral and print the result. You only need 3 or so digits beyond the decimal point.

# %% [markdown]
# ##### Email me 2 files.

# %% [markdown]
# File 1 is this ipynb file that contains your username in the file name. **NO** spaces in file name.

# %% [markdown]
# File 2 is a **pdf** of the same file, named in the same manner.

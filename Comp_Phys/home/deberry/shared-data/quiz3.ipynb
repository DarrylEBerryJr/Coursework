# %% [markdown]
# ### Quiz_3

# %% [markdown]
# #### Enter username here:

# %% [markdown]
# A cylindrical tank is filled with water. The tank has a valve on its bottom that is opened so the water drains. The height $h$ of the water above the tank's bottom at time $t$ is given by:

# %% [markdown]
# $$
# h(t) = 10\,(1- \frac{t}{100})^2,
# $$

# %% [markdown]
# where $t$ is the elapsed time after valve opening and is measured in minutes.

# %% [markdown]
# #### Q1. Find $t=t^{\ast}$ when $h=5$

# %% [markdown]
# #### Q2. Demonstrate that your estimate of $t^{\ast}$ is sensible by computing $h(t^{\ast})$.

# %% [markdown]
# Email me 2 files.

# %% [markdown]
# File 1 is this ipynb file that contains your username in the file name. **NO** spaces in file name.

# %% [markdown]
# File 2 is a **pdf** of the same file, named in the same manner.

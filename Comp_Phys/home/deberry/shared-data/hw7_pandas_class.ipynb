# %% [markdown]
# ### HW7 Pandas & CSV Files

# %% [markdown]
# #### Name

# %% [markdown]
# **Submission Directions:**  SOS. email me (`coan@smu.edu`) 2 files: the **pdf** of the notebook **and** the notebook itself.

# %% [markdown]
# #### Important

# %% [markdown]
# This homework is an assessment of how well you can work with pandas dataframes and csv files. Use those techniques to perform these exercises. For those on vacation from class for the past several sessions, the pandas notebook on hasui will be useful.

# %% [markdown]
# **1.** **Plot** the contents of the file `star_counts_vs_galactic_lat_simulated.csv`. The x-axis hould be the galactic latitude and the y-axis the number of visible stars. Label and title the plot sensibly. The diagram below illustrates galactic coordinates where `l` is the longitude and `b` is the latitude.
# You will need to copy the csv data file and `Galactic_coordinates.jpeg` to your working area.
#
# <img src="Galactic_coordinates.jpeg"
#      width="300"
#      style="display:block; margin-left:auto; margin-right:auto;">
#
# **Q** Given the shape of our galaxy (the "Milky Way") and where we live in it, explain briefly why the shape of this plot is sensible.
#
#
# **2.** The light that reaches us on Earth from the Sun is produced in the Sun's  **photosphere**, a dense and opaque region. Photons are absorbed, scattered and emitted many times before escaping. These repeated interactions drive the radiation field to a condition of thermal equilibrium with the photosphere, a condition to which the blackbody radiation distribution applies. Recall from Modern Physics that an object emitting radiation according to a blackbody distribution does not mean the object is black in color.
# Using the file `blackbody_spectrum_5800K.csv', **plot** the intensity of the solar radiation as a function of wavelength in nanometers for a blackbody at a temperature $T=5800\,$K, the temperature of the photosphere. The intensity units in the file have been scaled ("normalized") so that the maximum intensity is at 1.0. The intensity numbers measure the relative power emitted at a particular wavelength.
#
# **Q:** You should notice that the intensity peaks at a wavelength $\lambda = 500\,$nm. This is in the green part of the visible light spectrum. In my neighborhood the Sun does not look green. I doubt your neighborhood is that different. Why do we not see the Sun as green? Your explanation need not be long or complicated.

# %% [markdown]
# **3.** Earth's rotational axis is tilted at an angle $\theta \approx 23.44^{\circ}$ with respect to a perpendicular to the ecliptic plane and is the "reason for the seasons." The ecliptic is the plane of Earth's rotation about the Sun. See the figure. As Earth rotates about the Sun, the amount of light incident on the surface of each hemisophere changes, less in Winter, more in Summer, with Winters and Summers occurring at opposite times of the year in the two hemispheres.
#
# <img src="Axial_tilt_vs_tropical_and_polar_circles.svg.png"
#      width="500"
#      style="display:block; margin-left:auto; margin-right:auto;">
#
#
#
# The amount of power per square meter reaching the top of Earth's atmophere from the Sun ("solar irradiance") can be measured as a function of time throughout the year. Such data is contained in the file `solar_irradiance_seasonal.csv` and ijcludes data for about 1000 days. **Plot** the solar irradiance as a function of day for this data. Label the y-axis with proper units, label the x-axis and title the plot in a sensible way. **Calculate** the mean solar irradiance for this data and tell me what it is. Use correct units. This mean value of the solar irradiance is the maximum amount of power per square meter that you could collect and use for electricty if you were to build a solar energy station.
